# %%
import numpy as np
import pandas as pd

# %%
dict1={"name":["Harry","rohan","Ashwin","kavya"],
      "marks":[44,43,42,41],
      "city":["mumbai","Pune","Kharadi","Puneville"]}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks       city
# 0   Harry     44     mumbai
# 1   rohan     43       Pune
# 2  Ashwin     42    Kharadi
# 3   kavya     41  Puneville

# %%
df.to_csv("ex1pd.csv")

# %%
df.to_csv("windexx1pd.csv",index=False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  Harry     44  mumbai
# 1  rohan     43    Pune

# %%
df.tail(2)
# Out:
#      name  marks       city
# 2  Ashwin     42    Kharadi
# 3   kavya     41  Puneville

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   42.500000
# std     1.290994
# min    41.000000
# 25%    41.750000
# 50%    42.500000
# 75%    43.250000
# max    44.000000

# %%
df1=pd.read_csv("ex2.csv")

# %%
df1
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN   train no      speed       city
# 1         NaN      12222        100       Pune
# 2         NaN      23245         78     Mumbai
# 3         NaN      34342         87     nashik
# 4         NaN      78786         90      Latur
# 5         NaN      98987         80    Solapur
# 6         NaN      56564         67      Theur

# %%
df1.index=["first","Second","Third","forth","fifth","Six","seven"]

# %%
df1
# Out:
#         Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3
# first          NaN   train no      speed       city
# Second         NaN      12222        100       Pune
# Third          NaN      23245         78     Mumbai
# forth          NaN      34342         87     nashik
# fifth          NaN      78786         90      Latur
# Six            NaN      98987         80    Solapur
# seven          NaN      56564         67      Theur

# %%
ser=pd.Series(np.random.rand(34))

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
df2=pd.DataFrame(np.random.rand(332,5),index=np.arange(332))

# %%
df2.head(10)
# Out:
#           0         1         2         3         4
# 0  0.303360  0.048961  0.083029  0.890168  0.411184
# 1  0.223932  0.931231  0.551768  0.228349  0.481821
# 2  0.339609  0.098085  0.619087  0.369539  0.162321
# 3  0.666653  0.863723  0.961191  0.898086  0.704743
# 4  0.375678  0.499217  0.021998  0.132316  0.878104
# 5  0.901923  0.993377  0.302173  0.144060  0.171815
# 6  0.469641  0.026474  0.673238  0.766206  0.174258
# 7  0.957729  0.887408  0.756483  0.855017  0.329394
# 8  0.142924  0.830127  0.377866  0.697984  0.003597
# 9  0.437382  0.831056  0.127563  0.909564  0.066054

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.describe()
# Out:
#                 0           1           2           3           4
# count  332.000000  332.000000  332.000000  332.000000  332.000000
# mean     0.481313    0.539773    0.493992    0.501163    0.484817
# std      0.280156    0.288740    0.287180    0.279990    0.308921
# min      0.000723    0.006250    0.001800    0.007951    0.001667
# 25%      0.252741    0.300299    0.254257    0.251559    0.196182
# 50%      0.464504    0.568055    0.499022    0.512108    0.469578
# 75%      0.721087    0.804904    0.727904    0.737809    0.763846
# max      0.995877    0.997696    0.991649    0.999917    0.998540

# %%
df2.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
sort_index(axis=0,ascending=False)
# Out:
#             0         1         2         3         4
# 331  0.454517  0.915011  0.510992  0.424977  0.952254
# 330  0.762487  0.068961  0.872645  0.112943  0.837218
# 329  0.721721  0.971955  0.686512  0.999917  0.889282
# 328  0.578631  0.915731  0.657780  0.667063  0.761808
# 327  0.214165  0.359178  0.320428  0.806872  0.726064
# ..        ...       ...       ...       ...       ...
# 4    0.375678  0.499217  0.021998  0.132316  0.878104
# 3    0.666653  0.863723  0.961191  0.898086  0.704743
# 2    0.339609  0.098085  0.619087  0.369539  0.162321
# 1    0.223932     0.001  0.551768  0.228349  0.481821
# 0    0.303360  0.048961  0.083029  0.890168  0.411184
#
# [332 rows x 5 columns]

# %%
bdf2=df2

# %%
bdf2[0][0]=45
# Out:
# <ipython-input-31-5646a2a9fd81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bdf2[0][0]=45

# %%
df2.head(5)
# Out:
#            0         1         2         3         4
# 0  45.000000  0.048961  0.083029  0.890168  0.411184
# 1   0.223932     0.001  0.551768  0.228349  0.481821
# 2   0.339609  0.098085  0.619087  0.369539  0.162321
# 3   0.666653  0.863723  0.961191  0.898086  0.704743
# 4   0.375678  0.499217  0.021998  0.132316  0.878104

# %%
df2.columns=list("ABCDE")

# %%
df2.head(5)
# Out:
#            A         B         C         D         E
# 0  45.000000  0.048961  0.083029  0.890168  0.411184
# 1   0.223932     0.001  0.551768  0.228349  0.481821
# 2   0.339609  0.098085  0.619087  0.369539  0.162321
# 3   0.666653  0.863723  0.961191  0.898086  0.704743
# 4   0.375678  0.499217  0.021998  0.132316  0.878104

# %%
pdf2=df2.drop("E",axis=1)

# %%
bdf2
# Out:
#              A         B         C         D         E
# 0    45.000000  0.048961  0.083029  0.890168  0.411184
# 1     0.223932     0.001  0.551768  0.228349  0.481821
# 2     0.339609  0.098085  0.619087  0.369539  0.162321
# 3     0.666653  0.863723  0.961191  0.898086  0.704743
# 4     0.375678  0.499217  0.021998  0.132316  0.878104
# ..         ...       ...       ...       ...       ...
# 327   0.214165  0.359178  0.320428  0.806872  0.726064
# 328   0.578631  0.915731  0.657780  0.667063  0.761808
# 329   0.721721  0.971955  0.686512  0.999917  0.889282
# 330   0.762487  0.068961  0.872645  0.112943  0.837218
# 331   0.454517  0.915011  0.510992  0.424977  0.952254
#
# [332 rows x 5 columns]

# %%
pdf2
# Out:
#              A         B         C         D
# 0    45.000000  0.048961  0.083029  0.890168
# 1     0.223932     0.001  0.551768  0.228349
# 2     0.339609  0.098085  0.619087  0.369539
# 3     0.666653  0.863723  0.961191  0.898086
# 4     0.375678  0.499217  0.021998  0.132316
# ..         ...       ...       ...       ...
# 327   0.214165  0.359178  0.320428  0.806872
# 328   0.578631  0.915731  0.657780  0.667063
# 329   0.721721  0.971955  0.686512  0.999917
# 330   0.762487  0.068961  0.872645  0.112943
# 331   0.454517  0.915011  0.510992  0.424977
#
# [332 rows x 4 columns]

# %%
ndf2=df2.copy()

# %%
ndf2
# Out:
#              A         B         C         D         E
# 0    45.000000  0.048961  0.083029  0.890168  0.411184
# 1     0.223932     0.001  0.551768  0.228349  0.481821
# 2     0.339609  0.098085  0.619087  0.369539  0.162321
# 3     0.666653  0.863723  0.961191  0.898086  0.704743
# 4     0.375678  0.499217  0.021998  0.132316  0.878104
# ..         ...       ...       ...       ...       ...
# 327   0.214165  0.359178  0.320428  0.806872  0.726064
# 328   0.578631  0.915731  0.657780  0.667063  0.761808
# 329   0.721721  0.971955  0.686512  0.999917  0.889282
# 330   0.762487  0.068961  0.872645  0.112943  0.837218
# 331   0.454517  0.915011  0.510992  0.424977  0.952254
#
# [332 rows x 5 columns]

# %%
df2.loc[0][0]
# Out:
# 45.0

# %%
df2.loc[1:5:2,"A":"D":2]
# Out:
#           A         C
# 1  0.223932  0.551768
# 3  0.666653  0.961191
# 5  0.901923  0.302173

# %%
df2.loc[(df2['A']<0.3) & (df2['C']>0.1)]
# Out:
#             A         B         C         D         E
# 1    0.223932     0.001  0.551768  0.228349  0.481821
# 8    0.142924  0.830127  0.377866  0.697984  0.003597
# 11   0.036342  0.483971  0.425332  0.720207  0.941974
# 12   0.295648  0.875776  0.981025  0.153428  0.146187
# 17   0.060264  0.582181  0.923033  0.149224  0.093233
# ..        ...       ...       ...       ...       ...
# 319  0.253428   0.92764  0.403458  0.411135  0.896016
# 320  0.131466  0.684936  0.867051  0.276968  0.116962
# 322  0.252941  0.123825  0.800688  0.804429  0.457178
# 324  0.011529   0.85786  0.135042  0.324486  0.121256
# 327  0.214165  0.359178  0.320428  0.806872  0.726064
#
# [87 rows x 5 columns]

# %%
df2.iloc[0,4]
# Out:
# 0.41118368420431695

# %%
df2.iloc[[1,2],[0,1]]
# Out:
#           A         B
# 1  0.223932     0.001
# 2  0.339609  0.098085

# %%
df2.loc[[1,2],['A','B']]
# Out:
#           A         B
# 1  0.223932     0.001
# 2  0.339609  0.098085

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-9a4ab4cfcde2> in <module>
# ...

# %%
bdf2.drop([1,5],axis=0,inplace=True)

# %%
bdf2bdf
# Out:
#              A         B         C         D         E
# 0    45.000000  0.048961  0.083029  0.890168  0.411184
# 2     0.339609  0.098085  0.619087  0.369539  0.162321
# 3     0.666653  0.863723  0.961191  0.898086  0.704743
# 4     0.375678  0.499217  0.021998  0.132316  0.878104
# 6     0.469641  0.026474  0.673238  0.766206  0.174258
# ..         ...       ...       ...       ...       ...
# 327   0.214165  0.359178  0.320428  0.806872  0.726064
# 328   0.578631  0.915731  0.657780  0.667063  0.761808
# 329   0.721721  0.971955  0.686512  0.999917  0.889282
# 330   0.762487  0.068961  0.872645  0.112943  0.837218
# 331   0.454517  0.915011  0.510992  0.424977  0.952254
#
# [330 rows x 5 columns]

# %%
bdf2.reset_index(drop=2,inplace=True)

# %%
bdf2.head()
# Out:
#            A         B         C         D         E
# 0  45.000000  0.048961  0.083029  0.890168  0.411184
# 1   0.339609  0.098085  0.619087  0.369539  0.162321
# 2   0.666653  0.863723  0.961191  0.898086  0.704743
# 3   0.375678  0.499217  0.021998  0.132316  0.878104
# 4   0.469641  0.026474  0.673238  0.766206  0.174258

# %%
df2.isnull().sum()
# Out:
# A    0
# B    0
# C    0
# D    0
# E    0
# dtype: int64

# %%
df2["A"]=None

# %%
df2.head(5)
# Out:
#       A         B         C         D         E
# 0  None  0.048961  0.083029  0.890168  0.411184
# 1  None  0.098085  0.619087  0.369539  0.162321
# 2  None  0.863723  0.961191  0.898086  0.704743
# 3  None  0.499217  0.021998  0.132316  0.878104
# 4  None  0.026474  0.673238  0.766206  0.174258

# %%
df2['A'].isnull().sum()
# Out:
# 330

# %%
df2['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 325    False
# 326    False
# 327    False
# 328    False
# 329    False
# Name: B, Length: 330, dtype: bool

# %%
df2.loc[:,["C"]]=None

# %%
df2.isnull().sum()
# Out:
# A    330
# B      0
# C    330
# D      0
# E      0
# dtype: int64

# %%
df2.head(4)
# Out:
#       A         B     C         D         E
# 0  None  0.048961  None  0.890168  0.411184
# 1  None  0.098085  None  0.369539  0.162321
# 2  None  0.863723  None  0.898086  0.704743
# 3  None  0.499217  None  0.132316  0.878104

# %%
df3=pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman','Alfred'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip',np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT,np.nan],
                 "Surname":['Alfred', 'Batman', 'Catwoman',np.nan]})

# %%
df3
# Out:
#        name        toy       born   Surname
# 0    Alfred        NaN        NaT    Alfred
# 1    Batman  Batmobile 1940-04-25    Batman
# 2  Catwoman   Bullwhip        NaT  Catwoman
# 3    Alfred        NaN        NaT       NaN

# %%
df3.dropna(axis=1,how='any',inplace=False)
# Out:
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman
# 3    Alfred

# %%
df3
# Out:
#        name        toy       born   Surname
# 0    Alfred        NaN        NaT    Alfred
# 1    Batman  Batmobile 1940-04-25    Batman
# 2  Catwoman   Bullwhip        NaT  Catwoman
# 3    Alfred        NaN        NaT       NaN

# %%
df3.drop_duplicates(subset=['name'],keep='first')
# Out:
#        name        toy       born   Surname
# 0    Alfred        NaN        NaT    Alfred
# 1    Batman  Batmobile 1940-04-25    Batman
# 2  Catwoman   Bullwhip        NaT  Catwoman

# %%
df3.drop_duplicates(subset=['name'],keep='last')
# Out:
#        name        toy       born   Surname
# 1    Batman  Batmobile 1940-04-25    Batman
# 2  Catwoman   Bullwhip        NaT  Catwoman
# 3    Alfred        NaN        NaT       NaN

# %%
df3.drop_duplicates(subset=['name'],keep=False)
# Out:
#        name        toy       born   Surname
# 1    Batman  Batmobile 1940-04-25    Batman
# 2  Catwoman   Bullwhip        NaT  Catwoman

# %%
df3.shape
# Out:
# (4, 4)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   toy      2 non-null      object
#  2   born     1 non-null      datetime64[ns]
#  3   Surname  3 non-null      object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 256.0+ bytes

# %%
df3['toy'].value_counts(dropna=True)
# Out:
# Bullwhip     1
# Batmobile    1
# Name: toy, dtype: int64

# %%
df3['toy'].value_counts(dropna=False)
# Out:
# NaN          2
# Bullwhip     1
# Batmobile    1
# Name: toy, dtype: int64
